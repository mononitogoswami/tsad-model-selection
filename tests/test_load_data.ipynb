# %%
from tsadams.datasets.load import load_data
from tsadams.model_trainer.entities import ANOMALY_ARCHIVE_ENTITIES, MACHINES

# %%
train_data = load_data(
    dataset='anomaly_archive',
    group='train',
    entities=['128_UCR_Anomaly_GP711MarkerLFM5z2'],
    downsampling=10,
    min_length=256,
    root_dir='/home/scratch/mgoswami/datasets/',
    verbose=True)
print(train_data)
# Out:
# Number of datasets: 1
# Entity meta-data: {'name': '128_UCR_Anomaly_GP711MarkerLFM5z2', 'train_end': 5000, 'anomaly_start_in_test': 2175, 'anomaly_end_in_test': 2388}
# ------------------------------------------
# Entity:  128_UCR_Anomaly_GP711MarkerLFM5z2
# n_features:  1
# n_exogenous:  0
# n_time:  501
# Anomaly %:  0.0
# Mask %:  1.0
# ------------------------------------------
# ------------------------------------------
# Dataset(
# 	Dataset=128_UCR_Anomaly_GP711MarkerLFM5z2-train,
# 	n_entities=1,
# 	n_features=1,
# 	n_exogenous=0,
# 	total_time=501,
# 	anomaly_percentage=0.0,
# )
# ------------------------------------------
# Dataset(
# 	Dataset=128_UCR_Anomaly_GP711MarkerLFM5z2-train,
# 	n_entities=1,
# 	n_features=1,
# 	n_exogenous=0,
# 	total_time=501,
# 	anomaly_percentage=0.0,
# )

# %%
for machine in MACHINES:
    load_data(dataset='smd',
        group='train',
        entities=machine,
        downsampling=None,
        min_length=None,
        root_dir='/home/scratch/mgoswami/datasets/',
        verbose=True)
# Out:
# ------------------------------------------
# Entity:  machine-2-8
# n_features:  38
# n_exogenous:  0
# n_time:  23702
# Anomaly %:  0.0
# Mask %:  1.0
# ------------------------------------------
# ------------------------------------------
# Dataset(
# 	Dataset=smd-train,
# 	n_entities=1,
# 	n_features=38,
# 	n_exogenous=0,
# 	total_time=23702,
# 	anomaly_percentage=0.0,
# )
# ------------------------------------------
# ------------------------------------------
# Entity:  machine-1-8
# n_features:  38
# n_exogenous:  0
# n_time:  23698
# Anomaly %:  0.0
# Mask %:  1.0
# ------------------------------------------
# ------------------------------------------
# Dataset(
# 	Dataset=smd-train,
# 	n_entities=1,
# 	n_features=38,
# 	n_exogenous=0,
# 	total_time=23698,
# 	anomaly_percentage=0.0,
# )
# ------------------------------------------
# ------------------------------------------
# Entity:  machine-3-4
# n_features:  38
# n_exogenous:  0
# n_time:  23687
# Anomaly %:  0.0
# ...
